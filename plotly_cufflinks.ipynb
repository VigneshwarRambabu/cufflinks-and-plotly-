# %%
#plotly and cufflinks

# %%
#imports and data

# %%
import chart_studio.plotly as py
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1= pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())

# %%
df1
# Out:
#            A         B         C         D
# 0  -1.113409 -0.869579  0.142905 -0.875955
# 1   1.021676 -0.231548 -0.740281  0.865632
# 2  -1.554116  0.352914  1.571189 -0.620916
# 3   1.246598 -0.739408 -0.729700  1.967004
# 4   0.473360 -0.653006  0.696697  2.227429
# ..       ...       ...       ...       ...
# 95 -0.011114 -0.946154 -0.798072  0.332217
# 96  0.829432  0.780429  0.256950  0.577257
# 97 -0.497282  1.159752  0.953534 -0.818876
# 98 -0.177199  0.196974 -0.792296 -0.499541
# 99  0.166512  0.070964 -0.935208  0.613568
#
# [100 rows x 4 columns]

# %%
df2= pd.DataFrame({'Category':['A','B','C','D'],'Values':[32,34,56,72]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      34
# 2        C      56
# 3        D      72

# %%
df1
# Out:
#            A         B         C         D
# 0  -1.113409 -0.869579  0.142905 -0.875955
# 1   1.021676 -0.231548 -0.740281  0.865632
# 2  -1.554116  0.352914  1.571189 -0.620916
# 3   1.246598 -0.739408 -0.729700  1.967004
# 4   0.473360 -0.653006  0.696697  2.227429
# ..       ...       ...       ...       ...
# 95 -0.011114 -0.946154 -0.798072  0.332217
# 96  0.829432  0.780429  0.256950  0.577257
# 97 -0.497282  1.159752  0.953534 -0.818876
# 98 -0.177199  0.196974 -0.792296 -0.499541
# 99  0.166512  0.070964 -0.935208  0.613568
#
# [100 rows x 4 columns]

# %%
#basic line plot

# %%
df1.iplot()
# Out:
# <div>
#
#
#             <div id="8f83bd17-a049-4311-900e-21b3ff02108d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8f83bd17-a049-4311-900e-21b3ff02108d")) {
#                     Plotly.newPlot(
#                         '8f83bd17-a049-4311-900e-21b3ff02108d',
# ...

# %%
df1.iplot(kind='scatter',x='A',y='B', mode= 'markers', size=11)
# Out:
# <div>
#
#
#             <div id="c8117d4b-c5eb-42b3-9958-ebd88484b92d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c8117d4b-c5eb-42b3-9958-ebd88484b92d")) {
#                     Plotly.newPlot(
#                         'c8117d4b-c5eb-42b3-9958-ebd88484b92d',
# ...

# %%
 df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      34
# 2        C      56
# 3        D      72

# %%
#for categorical data

# %%
df2.iplot(kind='bar',x='Category',y='Values',color='blue')
# Out:
# <div>
#
#
#             <div id="cacd83e8-662d-424a-9740-a25ab96933ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cacd83e8-662d-424a-9740-a25ab96933ce")) {
#                     Plotly.newPlot(
#                         'cacd83e8-662d-424a-9740-a25ab96933ce',
#                         [{"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [32, 34, 56, 72]}],
# ...

# %%
#we can use some aggregate function in non categorical data use these plot such as count(), sum(),mean

# %%
#It plots for all the row wise values

# %%
df1.iplot(kind='bar',asImage=True)
# Out:
# <div>
#
#
#             <div id="4d4faf11-acef-47b9-b9f0-e188eb727e16" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4d4faf11-acef-47b9-b9f0-e188eb727e16")) {
#                     Plotly.newPlot(
#                         '4d4faf11-acef-47b9-b9f0-e188eb727e16',
# ...

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="9174c840-7f68-48ad-a9dc-12e783e40c19" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9174c840-7f68-48ad-a9dc-12e783e40c19")) {
#                     Plotly.newPlot(
#                         '9174c840-7f68-48ad-a9dc-12e783e40c19',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [22.7348390918071, -2.7180889443015994, 9.404655435252385, 10.083718757208485]}],
# ...

# %%
#boxplot

# %%
df1.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="1a831404-5874-4867-9ac7-e47fa2def2bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1a831404-5874-4867-9ac7-e47fa2def2bb")) {
#                     Plotly.newPlot(
#                         '1a831404-5874-4867-9ac7-e47fa2def2bb',
# ...

# %%
#3 D surface plot

# %%
df3 =pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="3ee79adf-69e5-4f1e-af7c-23e975274e58" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3ee79adf-69e5-4f1e-af7c-23e975274e58")) {
#                     Plotly.newPlot(
#                         '3ee79adf-69e5-4f1e-af7c-23e975274e58',
# ...

# %%
#histogram

# %%
df1["A"].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="9847a7eb-71b7-4748-ad7c-8e1eab784edd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9847a7eb-71b7-4748-ad7c-8e1eab784edd")) {
#                     Plotly.newPlot(
#                         '9847a7eb-71b7-4748-ad7c-8e1eab784edd',
# ...

# %%
df1 .iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="14ec3dc6-a5a7-4473-8d40-555c1dd65e42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("14ec3dc6-a5a7-4473-8d40-555c1dd65e42")) {
#                     Plotly.newPlot(
#                         '14ec3dc6-a5a7-4473-8d40-555c1dd65e42',
# ...

# %%
#Spread type Data Visualization

# %%
df1
# Out:
#            A         B         C         D
# 0  -1.113409 -0.869579  0.142905 -0.875955
# 1   1.021676 -0.231548 -0.740281  0.865632
# 2  -1.554116  0.352914  1.571189 -0.620916
# 3   1.246598 -0.739408 -0.729700  1.967004
# 4   0.473360 -0.653006  0.696697  2.227429
# ..       ...       ...       ...       ...
# 95 -0.011114 -0.946154 -0.798072  0.332217
# 96  0.829432  0.780429  0.256950  0.577257
# 97 -0.497282  1.159752  0.953534 -0.818876
# 98 -0.177199  0.196974 -0.792296 -0.499541
# 99  0.166512  0.070964 -0.935208  0.613568
#
# [100 rows x 4 columns]

# %%
#Use asImage = True to save the image

# %%
df1[['A','B']].iplot(kind='spread', asImage=True)
# Out:
# C:\Users\virambab\AppData\Local\Continuum\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\virambab\AppData\Local\Continuum\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="db506bee-35ff-4dcb-aefa-8eec04468489" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("db506bee-35ff-4dcb-aefa-8eec04468489")) {
#                     Plotly.newPlot(
# ...

# %%
#BUBBLE PLOT

# %%
 
df1.iplot(kind='bubble',x='A',y='B' ,size ='D',colorscale= 'set1' )
# Out:
# <div>
#
#
#             <div id="a68b10f3-1c06-4523-b351-5db0cedc42a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a68b10f3-1c06-4523-b351-5db0cedc42a7")) {
#                     Plotly.newPlot(
#                         'a68b10f3-1c06-4523-b351-5db0cedc42a7',
# ...

# %%
#Scattermatrix is same as pair plot, all elements should be numeric for this plot

# %%
df1.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="1f5c15a8-2d7f-4d5f-9669-72a71b43c1ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1f5c15a8-2d7f-4d5f-9669-72a71b43c1ec")) {
#                     Plotly.newPlot(
#                         '1f5c15a8-2d7f-4d5f-9669-72a71b43c1ec',
# ...

# %%
df1.iplot(kind='heatmap',colorscale='spectral')
# Out:
# <div>
#
#
#             <div id="a54500af-cb4c-43df-88a1-f3b29e734fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a54500af-cb4c-43df-88a1-f3b29e734fb9")) {
#                     Plotly.newPlot(
#                         'a54500af-cb4c-43df-88a1-f3b29e734fb9',
# ...

# %%
df4 = pd.DataFrame({"Country":['Ind','Aus','Newz'],'pop':[333,444,555]})
df4
# Out:
#   Country  pop
# 0     Ind  333
# 1     Aus  444
# 2    Newz  555

# %%
import plotly.express as px
pie = px.pie( df4, values='pop',names= 'Country')
pie.show()
# Out:
# <div>
#
#
#             <div id="6202212e-809c-4575-b50f-ea372956b1f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6202212e-809c-4575-b50f-ea372956b1f3")) {
#                     Plotly.newPlot(
#                         '6202212e-809c-4575-b50f-ea372956b1f3',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Country=%{label}<br>pop=%{value}<extra></extra>", "labels": ["Ind", "Aus", "Newz"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [333, 444, 555]}],
# ...

# %%
#map plotting

# %%
import chart_studio.plotly as py
import plotly.graph_objects as go

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot, plot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
 data= dict(type='choropleth',
          locations=['AZ',"CA","NY"],
          locationmode='USA-states',
          text=['arizona','cali','new york'],
           colorscale='Portland',
           z=['1.','2.','3.'],
           colorbar={'title':'COLOR BAR TITLE : USA'})

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': ['AZ', 'CA', 'NY'],
#  'locationmode': 'USA-states',
#  'text': ['arizona', 'cali', 'new york'],
#  'colorscale': 'Portland',
#  'z': ['1.', '2.', '3.'],
#  'colorbar': {'title': 'COLOR BAR TITLE : USA'}}

# %%
layout=dict(geo={'scope':'usa'})

# %%
layout
# Out:
# {'geo': {'scope': 'usa'}}

# %%
 chloromap  = go.Figure(data=[data], layout = layout)

# %%
iplot(chloromap)
# Out:
# <div>
#
#
#             <div id="284a5b9d-286c-4679-9cce-b3cdb43772ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("284a5b9d-286c-4679-9cce-b3cdb43772ce")) {
#                     Plotly.newPlot(
#                         '284a5b9d-286c-4679-9cce-b3cdb43772ce',
#                         [{"colorbar": {"title": {"text": "COLOR BAR TITLE : USA"}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]], "locationmode": "USA-states", "locations": ["AZ", "CA", "NY"], "text": ["arizona", "cali", "new york"], "type": "choropleth", "z": ["1.", "2.", "3."]}],
# ...

# %%
#Choropleth on real data

# %%
df = pd.read_csv('2011_US_AGRI_Exports')

# %%
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           50 non-null     object
#  1   state          50 non-null     object
#  2   category       50 non-null     object
#  3   total exports  50 non-null     float64
#  4   beef           50 non-null     float64
#  5   pork           50 non-null     float64
#  6   poultry        50 non-null     float64
#  7   dairy          50 non-null     float64
#  8   fruits fresh   50 non-null     float64
#  9   fruits proc    50 non-null     float64
#  10  total fruits   50 non-null     float64
#  11  veggies fresh  50 non-null     float64
#  12  veggies proc   50 non-null     float64
#  13  total veggies  50 non-null     float64
#  14  corn           50 non-null     float64
#  15  wheat          50 non-null     float64
#  16  cotton         50 non-null     float64
# ...

# %%
 df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
data = dict(type='choropleth',
           locations=df['code'],
           locationmode='USA-states',
           text=df['state'],
           colorscale='Reds',
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           z=df['total exports'],
           colorbar = {'title':"Total exports of US regions"})

# %%
 layout = dict( title ='2011 US AGRICULTURE EXPORTS BY STATE',
               geo=dict(scope= 'usa', showlakes=True,lakecolor='rgb(85,173,240)'))

# %%
chloromap1 = go.Figure(data= [data],layout= layout)

# %%
iplot(chloromap1)
# Out:
# <div>
#
#
#             <div id="157a9cc6-9f99-4861-a761-a27bb6697764" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("157a9cc6-9f99-4861-a761-a27bb6697764")) {
#                     Plotly.newPlot(
#                         '157a9cc6-9f99-4861-a761-a27bb6697764',
# ...

# %%
df = pd.read_csv('2014_World_GDP')

# %%
df.head()
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
data=dict(type='choropleth',
         locations=df['CODE'],
          text=df['COUNTRY'],colorscale = 'Viridis',
         z=df['GDP (BILLIONS)'],
          colorbar={'title':'GDP in BILLIONS USD'}
         )

# %%
layout=dict(title='2014_World_GDP', geo=dict(showlakes=False,projection={'type':'orthographic'}))

# %%
go.Figure(data=[data],layout= layout)
# Out:
# <div>
#
#
#             <div id="60295fd3-09d8-4b16-8565-5d7f79dde55d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60295fd3-09d8-4b16-8565-5d7f79dde55d")) {
#                     Plotly.newPlot(
#                         '60295fd3-09d8-4b16-8565-5d7f79dde55d',
# ...
